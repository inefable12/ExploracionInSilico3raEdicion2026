# %% [markdown]
# # **Práctica 1**

# %% [markdown]
# **Ejercicio 1:** Teniendo en consideración la siguiente cadena: “Las listas en Python son una herramienta poderosa y versátil que te permiten almacenar y trabajar con colecciones de elementos de distintos tipos”, realizar las siguientes acciones
# 1.   ¿Cuál es el tamaño de la cadena?
# 1.   Obtener la frase: “herramienta poderosa y versátil”
# 1.   Obtener la frase: “almacenar y trabajar con colecciones”
# 1.   Componer: “Las listas son una herramienta poderosa”
# 1.   Componer :”herramienta poderosa y versátil de elementos de distintos tipos”
# 1.   Componer : “Las listas  permiten almacenar y trabajar con colecciones de distintos tipos ”
# 1.   Componer : “Python trabaja con distintos tipos”
# 1.   Componer : “PythonPythonPythonPython”

# %% [markdown]
# **Ejercicio 2:** Usando la cadena del ejercicio 1, indica que imprime (la variable mensaje guarda la cadena):
# 1.  mensaje[2:10]
# 1.  mensaje[12:50]
# 1.  mensaje[:40]
# 1.  mensaje[40:200]
# 1.  mensaje[:]
# 1.  mensaje[3:15] + mensaje[5:40]
# 1.  mensaje[10:35]*3

# %% [markdown]
# **Ejercicio 3:** Los teléfonos de una empresa tienen el siguiente formato prefijo-número-extensión donde el prefijo es el código del país +34, y la extensión tiene dos dígitos (por ejemplo +34-913724710-56). Escribir un programa que pregunte por un número de teléfono con este formato y muestre por pantalla el número de teléfono sin el prefijo y la extensión.

# %% [markdown]
# **Ejercicio 4:** Escribir un programa que pregunte por consola el precio de un producto en dólares con dos decimales y muestre el valor en soles. Posteriormente, pedir al usuario que indique la posición del punto decimal, para que el resultado sea el siguiente:
#
# ---
# Introduce el precio del producto con dos decimales:  12.45
#
# En soles 45.6915
#
# Indicar posición del punto: 2
#
# 45 soles con  6915 céntimos

# %% [markdown]
# **Ejercicio 5:** Realizar el ejercicio anterior usando find()

# %% [markdown]
# **Ejercicio 6:** Pedir al usuario que introduzca un texto e intercambie las vocales a por o y la e por i.

# %% [markdown]
# **Ejercicio 7:** Ingresar una fecha de formato dd/mm/aaaa e imprimir en pantalla en el siguiente formato: mm/dd/aaaa.

# %% [markdown]
# **Ejercicio 8:** Ingrese  por consola la siguiente frase: “Python no le importa si usted usa comillas simples o dobles”, e imprima cada palabra en una diferente linea.
